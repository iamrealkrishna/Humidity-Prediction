# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"F:\misc\UPASI Project\final\\DailyMet.xlsx")
df.head(10)
# Out:
#    Year  Month  Day Temperature min  Temperature max  Humidity 8:30  \
# 0  1952      1    1               5        23.888889            NaN
# 1  1952      1    2         9.44444        23.888889            NaN
# 2  1952      1    3         13.3333        25.000000            NaN
# 3  1952      1    4         12.2222        22.777778            NaN
# 4  1952      1    5         9.44444        22.777778            NaN
# 5  1952      1    6         16.1111        25.555556            NaN
# 6  1952      1    7         16.1111        19.444444            NaN
# 7  1952      1    8         7.77778        22.777778            NaN
# 8  1952      1    9              10        23.333333            NaN
# 9  1952      1   10         7.77778        24.444444            NaN
#
#    Humidity 2:30 Rainfall Inches  Rainfall mm
# 0            NaN               0        0.000
# 1            NaN            0.85       21.590
# 2            NaN               0        0.000
# 3            NaN               0        0.000
# 4            NaN               0        0.000
# 5            NaN               0        0.000
# 6            NaN               0        0.000
# 7            NaN               0        0.000
# 8            NaN               0        0.000
# 9            NaN            0.04        1.016

# %%
df["Humidity 8:30"]=df["Humidity 8:30"].astype(float)
df["Humidity 2:30"]=df["Humidity 2:30"].astype(float)
df.head()
# Out:
#    Year  Month  Day Temperature min  Temperature max  Humidity 8:30  \
# 0  1952      1    1               5        23.888889            NaN
# 1  1952      1    2         9.44444        23.888889            NaN
# 2  1952      1    3         13.3333        25.000000            NaN
# 3  1952      1    4         12.2222        22.777778            NaN
# 4  1952      1    5         9.44444        22.777778            NaN
#
#    Humidity 2:30 Rainfall Inches  Rainfall mm
# 0            NaN               0         0.00
# 1            NaN            0.85        21.59
# 2            NaN               0         0.00
# 3            NaN               0         0.00
# 4            NaN               0         0.00

# %%
df.drop(df[(df['Day']>28) & (df['Month']==2) & (df['Year']%4!=0)].index,inplace=True)
df.drop(df[(df['Day']>29) & (df['Month']==2) & (df['Year']%4==0)].index,inplace=True)
df.drop(df[(df['Day']>30) & ((df['Month']==4)|(df['Month']==6)|(df['Month']==9)|(df['Month']==11))].index,inplace=True)

# %%
date = [str(y)+'-'+str(m)+'-'+str(d) for y, m, d in zip(df.Year, df.Month, df.Day)]

# %%
df.index = pd.to_datetime(date)

# %%
df['date'] = df.index
df['dayofyear']=df['date'].dt.dayofyear
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#             Year  Month  Day Temperature min  Temperature max  Humidity 8:30  \
# 1952-01-01  1952      1    1               5        23.888889            NaN
# 1952-01-02  1952      1    2         9.44444        23.888889            NaN
# 1952-01-03  1952      1    3         13.3333        25.000000            NaN
# 1952-01-04  1952      1    4         12.2222        22.777778            NaN
# 1952-01-05  1952      1    5         9.44444        22.777778            NaN
#
#             Humidity 2:30 Rainfall Inches  Rainfall mm  dayofyear
# 1952-01-01            NaN               0         0.00          1
# 1952-01-02            NaN            0.85        21.59          2
# 1952-01-03            NaN               0         0.00          3
# 1952-01-04            NaN               0         0.00          4
# 1952-01-05            NaN               0         0.00          5

# %%
df.size
# Out:
# 251950

# %%
df['Humidity'] = df[['Humidity 8:30', 'Humidity 2:30']].mean(axis=1)

# %%
df.head()
# Out:
#             Year  Month  Day Temperature min  Temperature max  Humidity 8:30  \
# 1952-01-01  1952      1    1               5        23.888889            NaN
# 1952-01-02  1952      1    2         9.44444        23.888889            NaN
# 1952-01-03  1952      1    3         13.3333        25.000000            NaN
# 1952-01-04  1952      1    4         12.2222        22.777778            NaN
# 1952-01-05  1952      1    5         9.44444        22.777778            NaN
#
#             Humidity 2:30 Rainfall Inches  Rainfall mm  dayofyear  Humidity
# 1952-01-01            NaN               0         0.00          1       NaN
# 1952-01-02            NaN            0.85        21.59          2       NaN
# 1952-01-03            NaN               0         0.00          3       NaN
# 1952-01-04            NaN               0         0.00          4       NaN
# 1952-01-05            NaN               0         0.00          5       NaN

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#             Year  Month  Day Temperature min  Temperature max  Humidity 8:30  \
# 1952-01-01  1952      1    1               5        23.888889            0.0
# 1952-01-02  1952      1    2         9.44444        23.888889            0.0
# 1952-01-03  1952      1    3         13.3333        25.000000            0.0
# 1952-01-04  1952      1    4         12.2222        22.777778            0.0
# 1952-01-05  1952      1    5         9.44444        22.777778            0.0
# ...          ...    ...  ...             ...              ...            ...
# 2020-12-27  2020     12   27               1        24.000000           87.0
# 2020-12-28  2020     12   28               7        25.000000           88.0
# 2020-12-29  2020     12   29               9        25.000000           89.0
# 2020-12-30  2020     12   30              13        24.000000           89.0
# 2020-12-31  2020     12   31              13        24.000000           89.0
#
#             Humidity 2:30 Rainfall Inches  Rainfall mm  dayofyear  Humidity
# 1952-01-01            0.0               0        0.000          1       0.0
# 1952-01-02            0.0            0.85       21.590          2       0.0
# 1952-01-03            0.0               0        0.000          3       0.0
# 1952-01-04            0.0               0        0.000          4       0.0
# 1952-01-05            0.0               0        0.000          5       0.0
# ...                   ...             ...          ...        ...       ...
# 2020-12-27           59.0               0        0.000        362      73.0
# 2020-12-28           59.0               0        0.000        363      73.5
# 2020-12-29           75.0          Traces        0.000        364      82.0
# 2020-12-30           81.0               0        0.000        365      85.0
# 2020-12-31           90.0            0.34        8.636        366      89.5
#
# [25195 rows x 11 columns]

# %%
df.plot(x='Year',y='Humidity',style='.', figsize=(15,5))

# %%
df = df.loc[df["Year"] >= 1986]
df = df.loc[df["Humidity"] < 125]
df
# Out:
#             Year  Month  Day Temperature min  Temperature max  Humidity 8:30  \
# 1986-01-01  1986      1    1               3             22.0           85.0
# 1986-01-02  1986      1    2               5             26.0           86.0
# 1986-01-03  1986      1    3               3             23.0           86.0
# 1986-01-04  1986      1    4               5             23.0           85.0
# 1986-01-05  1986      1    5               4             23.0           86.0
# ...          ...    ...  ...             ...              ...            ...
# 2020-12-27  2020     12   27               1             24.0           87.0
# 2020-12-28  2020     12   28               7             25.0           88.0
# 2020-12-29  2020     12   29               9             25.0           89.0
# 2020-12-30  2020     12   30              13             24.0           89.0
# 2020-12-31  2020     12   31              13             24.0           89.0
#
#             Humidity 2:30 Rainfall Inches  Rainfall mm  dayofyear  Humidity
# 1986-01-01           55.0               0        0.000          1      70.0
# 1986-01-02           61.0               0        0.000          2      73.5
# 1986-01-03           35.0               0        0.000          3      60.5
# 1986-01-04           61.0               0        0.000          4      73.0
# 1986-01-05           75.0               0        0.000          5      80.5
# ...                   ...             ...          ...        ...       ...
# 2020-12-27           59.0               0        0.000        362      73.0
# 2020-12-28           59.0               0        0.000        363      73.5
# 2020-12-29           75.0          Traces        0.000        364      82.0
# 2020-12-30           81.0               0        0.000        365      85.0
# 2020-12-31           90.0            0.34        8.636        366      89.5
#
# [12776 rows x 11 columns]

# %%
df.plot(x='Year',y='Humidity',style='.', figsize=(15,5))

# %%
train = df.loc[df['Year'] <=2012]
test = df.loc[df['Year'] > 2012]

# %%
X_train=train.drop(['Temperature min','Temperature max', 'Humidity 8:30', 'Humidity 2:30','Rainfall Inches', 'Rainfall mm', 'dayofyear'], axis=1)
Y_train=train['Humidity']

# %%
X_train.head()
# Out:
#             Year  Month  Day  Humidity
# 1986-01-01  1986      1    1      70.0
# 1986-01-02  1986      1    2      73.5
# 1986-01-03  1986      1    3      60.5
# 1986-01-04  1986      1    4      73.0
# 1986-01-05  1986      1    5      80.5

# %%
X_test=test.drop(['Temperature min','Temperature max', 'Humidity 8:30', 'Humidity 2:30','Rainfall Inches', 'Rainfall mm', 'dayofyear'], axis=1)
Y_test=test['Humidity']

# %%
X_test.head(10)
# Out:
#             Year  Month  Day  Humidity
# 2013-01-01  2013      1    1      69.5
# 2013-01-02  2013      1    2      63.0
# 2013-01-03  2013      1    3      72.0
# 2013-01-04  2013      1    4      80.5
# 2013-01-05  2013      1    5      66.5
# 2013-01-06  2013      1    6      73.5
# 2013-01-07  2013      1    7      84.5
# 2013-01-08  2013      1    8      82.0
# 2013-01-09  2013      1    9      83.5
# 2013-01-10  2013      1   10      77.5

# %%
X_train.fillna(0, inplace=True)
Y_train.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)
Y_test.fillna(0, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
from sklearn.svm import SVR
regressor=SVR(gamma='scale',kernel='poly',degree=5)
regressor.fit(X_train,Y_train)
Y_pred = regressor.predict(X_test)

# %%
regressor.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 5,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'poly',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
df1 = pd.DataFrame({'Actual Humidity': Y_test, 'Predicted Humidity': Y_pred})  
df1[df1['Predicted Humidity']>=1].head(10)
# Out:
#             Actual Humidity  Predicted Humidity
# 2013-01-01               69           75.691184
# 2013-01-02               63           72.206552
# 2013-01-03               72           77.433226
# 2013-01-04               80           82.085684
# 2013-01-05               66           73.946146
# 2013-01-06               73           78.012727
# 2013-01-07               84           84.412999
# 2013-01-08               82           83.247834
# 2013-01-09               83           83.829612
# 2013-01-10               77           80.336706

# %%
plt.figure(figsize=(20,10))
plt.scatter(X_test['Day'],Y_test,color='red')
plt.plot(X_test['Day'],Y_test,color='green')
plt.plot(X_test['Day'],Y_pred,color='blue')

# %%
df1.plot(figsize=(15,4))
df1.plot(subplots=True, figsize=(15,6))
df1.plot( y=["Actual Humidity"], style='.')

# %%
from sklearn.metrics import r2_score 
r2 = r2_score(Y_test, Y_pred) 
r2
# Out:
# 0.8310059809256215

# %%
from sklearn.metrics import mean_absolute_error as mae

mae(Y_test, Y_pred,multioutput='uniform_average')
# Out:
# 3.427513135058274

# %%
import math
MSE = np.square(np.subtract(Y_test, Y_pred)).mean() 
 
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 4.414162943482264

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_pred)
# Out:
# 19.48483449161201

# %%
from sklearn.metrics import mean_absolute_error
mape = mean_absolute_error(Y_test, Y_pred)*100
print(mape)
# Out:
# 342.7513135058274

# %%
X_train.fillna(0, inplace=True)
Y_train.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)
Y_test.fillna(0, inplace=True)
X_train=X_train.astype('int')
Y_train=Y_train.astype('int')
X_test=X_test.astype('int')
Y_test=Y_test.astype('int')

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=365,learning_rate='adaptive')
mlp.fit(X_train,Y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(13, 13, 13), learning_rate='adaptive',
#               max_iter=365)

# %%
mlp.get_params()
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'batch_size': 'auto',
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'early_stopping': False,
#  'epsilon': 1e-08,
#  'hidden_layer_sizes': (13, 13, 13),
#  'learning_rate': 'adaptive',
#  'learning_rate_init': 0.001,
#  'max_fun': 15000,
#  'max_iter': 365,
#  'momentum': 0.9,
#  'n_iter_no_change': 10,
#  'nesterovs_momentum': True,
#  'power_t': 0.5,
#  'random_state': None,
#  'shuffle': True,
#  'solver': 'adam',
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': False,
#  'warm_start': False}

# %%
Y_pred1 = mlp.predict(X_test)

# %%
df2 = pd.DataFrame({'Actual Humidity': Y_test, 'Predicted Humidity': Y_pred1})  
df2[df2['Predicted Humidity']>=1].head(10)
# Out:
#             Actual Humidity  Predicted Humidity
# 2013-01-01               69                  69
# 2013-01-02               63                  63
# 2013-01-03               72                  72
# 2013-01-04               80                  80
# 2013-01-05               66                  65
# 2013-01-06               73                  72
# 2013-01-07               84                  83
# 2013-01-08               82                  81
# 2013-01-09               83                  82
# 2013-01-10               77                  76

# %%
df2.plot(figsize=(15,4))
df2.plot(subplots=True, figsize=(15,6))
df2.plot( y=["Actual Humidity"], style='.')

# %%
from sklearn.metrics import r2_score 
r2 = r2_score(Y_test, Y_pred1) 
r2
# Out:
# 0.990367835254072

# %%
from sklearn.metrics import mean_absolute_error as mae

mae(Y_test, Y_pred1,multioutput='uniform_average')
# Out:
# 0.796302636083533

# %%
import math
MSE = np.square(np.subtract(Y_test, Y_pred1)).mean() 
 
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 1.0538399162032273

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_pred1)
# Out:
# 1.1105785689832248

# %%
from sklearn import svm
from sklearn.svm import SVC
model = svm.SVC(gamma='scale',kernel='poly',degree=12)
model.fit(X_train, Y_train)
# Out:
# SVC(degree=12, kernel='poly')

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 12,
#  'gamma': 'scale',
#  'kernel': 'poly',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
Y_test
# Out:
# 2013-01-01    69
# 2013-01-02    63
# 2013-01-03    72
# 2013-01-04    80
# 2013-01-05    66
#               ..
# 2020-12-27    73
# 2020-12-28    73
# 2020-12-29    82
# 2020-12-30    85
# 2020-12-31    89
# Name: Humidity, Length: 2921, dtype: int32

# %%
Y_pred2 = model.predict(X_test)

# %%
df3 = pd.DataFrame({'Actual Humidity': Y_test, 'Predicted Humidity': Y_pred2})  
df3[df3['Predicted Humidity']!=0].head(10)
# Out:
#             Actual Humidity  Predicted Humidity
# 2013-01-01               69                  73
# 2013-01-02               63                  69
# 2013-01-03               72                  77
# 2013-01-04               80                  81
# 2013-01-05               66                  73
# 2013-01-06               73                  77
# 2013-01-07               84                  86
# 2013-01-08               82                  81
# 2013-01-09               83                  81
# 2013-01-10               77                  77

# %%
Y_test
# Out:
# 2013-01-01    69
# 2013-01-02    63
# 2013-01-03    72
# 2013-01-04    80
# 2013-01-05    66
#               ..
# 2020-12-27    73
# 2020-12-28    73
# 2020-12-29    82
# 2020-12-30    85
# 2020-12-31    89
# Name: Humidity, Length: 2921, dtype: int32

# %%
df3.plot(figsize=(15,4))
df3.plot(subplots=True, figsize=(15,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B875391250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001B8753B1D60>],
#       dtype=object)

# %%
r2 = r2_score(Y_test, Y_pred2) 
r2
# Out:
# 0.9327114311121392

# %%
from sklearn.metrics import mean_absolute_error as mae

mae(Y_test, Y_pred2,multioutput='uniform_average')
# Out:
# 1.3392673741869223

# %%
import math
MSE = np.square(np.subtract(Y_test, Y_pred2)).mean() 
 
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 2.785372856797903

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_pred2)
# Out:
# 7.758301951386511

# %%
from sklearn.neighbors import KNeighborsClassifier
neig = KNeighborsClassifier(n_neighbors=6)
neig.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
neig.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 6,
#  'p': 2,
#  'weights': 'uniform'}

# %%
Y_test3 = test['Humidity']
Y_pred3 = neig.predict(X_test)

# %%
df4 = pd.DataFrame({'Actual Humidity': Y_test, 'Predicted Humidity': Y_pred3})  
df4[df4['Predicted Humidity']>=1].head(10)
# Out:
#             Actual Humidity  Predicted Humidity
# 2013-01-01               69                  69
# 2013-01-02               63                  62
# 2013-01-03               72                  74
# 2013-01-04               80                  81
# 2013-01-05               66                  63
# 2013-01-06               73                  73
# 2013-01-07               84                  85
# 2013-01-08               82                  81
# 2013-01-09               83                  82
# 2013-01-10               77                  77

# %%
df4.plot(figsize=(15,4))
df4.plot(subplots=True, figsize=(15,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B875EDEB80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001B875F0A220>],
#       dtype=object)

# %%
r2 = r2_score(Y_test, Y_pred3) 
r2
# Out:
# 0.9875916102117037

# %%
from sklearn.metrics import mean_absolute_error as mae

mae(Y_test, Y_pred3,multioutput='uniform_average')
# Out:
# 0.6617596713454297

# %%
import math
MSE = np.square(np.subtract(Y_test, Y_pred3)).mean() 
 
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 0.8886042349318384

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_pred3)
# Out:
# 1.4306744265662443
